# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import koreanize_matplotlib
# %matplotlib inline

# %%
train = pd.read_csv('train.csv',parse_dates=['datetime'])

# %%
train.shape
# Out:
# (10886, 12)

# %%
train.columns
# Out:
# Index(['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp',
#        'atemp', 'humidity', 'windspeed', 'casual', 'registered', 'count'],
#       dtype='object')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  datetime64[ns]
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(8)
# memory usage: 1020.7 KB

# %%
train.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
# 날짜 시간 데이터에서 년월일시분 분리
train['year'] = train['datetime'].dt.year
train['month'] = train['datetime'].dt.month
train['day'] = train['datetime'].dt.day
train['hour'] = train['datetime'].dt.hour
train['minute'] = train['datetime'].dt.minute
train['second'] = train['datetime'].dt.second
train
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 0     2011-01-01 00:00:00       1        0           0        1   9.84
# 1     2011-01-01 01:00:00       1        0           0        1   9.02
# 2     2011-01-01 02:00:00       1        0           0        1   9.02
# 3     2011-01-01 03:00:00       1        0           0        1   9.84
# 4     2011-01-01 04:00:00       1        0           0        1   9.84
# ...                   ...     ...      ...         ...      ...    ...
# 10881 2012-12-19 19:00:00       4        0           1        1  15.58
# 10882 2012-12-19 20:00:00       4        0           1        1  14.76
# 10883 2012-12-19 21:00:00       4        0           1        1  13.94
# 10884 2012-12-19 22:00:00       4        0           1        1  13.94
# 10885 2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count  year  month  \
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  datetime64[ns]
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
#  12  year        10886 non-null  int64
#  13  month       10886 non-null  int64
#  14  day         10886 non-null  int64
#  15  hour        10886 non-null  int64
#  16  minute      10886 non-null  int64
#  17  second      10886 non-null  int64
# ...

# %%
train.dtypes
# Out:
# datetime      datetime64[ns]
# season                 int64
# holiday                int64
# workingday             int64
# weather                int64
# temp                 float64
# atemp                float64
# humidity               int64
# windspeed            float64
# casual                 int64
# registered             int64
# count                  int64
# year                   int64
# month                  int64
# day                    int64
# hour                   int64
# minute                 int64
# second                 int64
# dtype: object

# %%
train.isna().sum()
# Out:
# datetime      0
# season        0
# holiday       0
# workingday    0
# weather       0
# temp          0
# atemp         0
# humidity      0
# windspeed     0
# casual        0
# registered    0
# count         0
# year          0
# month         0
# day           0
# hour          0
# minute        0
# second        0
# dtype: int64

# %% [markdown]
# ### barplot은 y축에 평균값을 구해주는 시각화 메서드이다.

# %%
# 연도별 대여량 시각화
year=sns.barplot(data=train,x='year',y='count')
plt.savefig('img/year.png')

# %%
# 월별 대여량 시각화
month = sns.barplot(data=train,x='month',y='count')
plt.savefig('img/month.png')

# %%
# 일별 대여량 시각화
day = sns.barplot(data=train,x='day',y='count')
plt.savefig('img/day.png')

# %%
# 시간별 대여량 시각화
hour = sns.barplot(data=train,x='hour',y='count')
plt.savefig('img/hour.png')

# %%
train[train['hour']==0]['count'].sum()
# Out:
# 25088

# %%
len(train[train['hour']==0]['count'].value_counts().index)
# Out:
# 145

# %%
# 시간별 대여량 시각화
pp_hour = sns.pointplot(data=train,x='hour',y='count')
plt.savefig('img/pp_hour.png')

# %%
# 평일 및 휴일 대여량 시각화
sns.pointplot(data=train,x='hour',y='count',hue='workingday')
plt.savefig('img/pp_hour_workingday.png')

# %%
# 날씨별 대여량 시각화
# 1 : 맑은 날씨
# 2 : 안개
# 3 : 가벼운 눈, 비
# 4 : 폭설, 폭우
sns.pointplot(data=train,x='hour',y='count',hue='weather')
plt.savefig('img/pp_hour_weather.png')

# %%
train[train['weather']==4]['count'].sum()
# Out:
# 164

# %%
# 계절별 대여량을 시간에 따라 시각화
# 1 : 봄, 2 : 여름, 3 : 가을, 4 : 겨울
sns.pointplot(data=train,x='hour',y='count',hue='season')
plt.savefig('img/pp_hour_season.png')
