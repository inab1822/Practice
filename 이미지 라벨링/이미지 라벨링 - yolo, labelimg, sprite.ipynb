# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15305, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 15305 (delta 0), reused 2 (delta 0), pack-reused 15300
# Receiving objects: 100% (15305/15305), 14.19 MiB | 29.53 MiB/s, done.
# Resolving deltas: 100% (10496/10496), done.

# %%
# %cd yolov5 
# !pip install -r requirements.txt
# Out:
# /content/yolov5
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 KB 17.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 75.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 8.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 57.4.0
#     Uninstalling setuptools-57.4.0:
#       Successfully uninstalled setuptools-57.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.9.0 requires jedi>=0.10, which is not installed.
# cvxpy 1.2.3 requires setuptools<=64.0.2, but you have setuptools 67.6.0 which is incompatible.
# ...

# %%
# !python train.py --data /content/drive/MyDrive/sprite/data.yaml --cfg /content/yolov5/models/yolov5s.yaml --weights yolov5s.pt --batch 8 --epochs 200 --name sprite
# Out:
# train: weights=yolov5s.pt, cfg=/content/yolov5/models/yolov5s.yaml, data=/content/drive/MyDrive/sprite/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=200, batch_size=8, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=sprite, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-120-g3e55763 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
# !python val.py --data "/content/drive/MyDrive/sprite/data.yaml" --img 1280 --weights "/content/yolov5/runs/train/sprite/weights/best.pt"
# Out:
# val: data=/content/drive/MyDrive/sprite/data.yaml, weights=['/content/yolov5/runs/train/sprite/weights/best.pt'], batch_size=32, imgsz=1280, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-120-g3e55763 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# val: Scanning /content/drive/MyDrive/sprite/labels.cache... 46 images, 0 backgrounds, 0 corrupt: 100% 46/46 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:07<00:00,  3.80s/it]
#                    all         46         93      0.628      0.774      0.741      0.333
# ...

# %%
# !python detect.py --img 1280 --weights "/content/yolov5/runs/train/sprite2/weights/best.pt" --source "/content/drive/MyDrive/sprite/스프라이트_5.jpg"
# Out:
# detect: weights=['/content/yolov5/runs/train/sprite2/weights/best.pt'], source=/content/drive/MyDrive/sprite/스프라이트_5.jpg, data=data/coco128.yaml, imgsz=[1280, 1280], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-119-g5543b89 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/drive/MyDrive/sprite/스프라이트_5.jpg: 1280x1280 3 sprites, 34.4ms
# Speed: 1.5ms pre-process, 34.4ms inference, 1.6ms NMS per image at shape (1, 3, 1280, 1280)
# Results saved to runs/detect/exp

# %%
# !python detect.py --img 1280 --weights "/content/yolov5/runs/train/sprite/weights/best.pt" --source "/content/drive/MyDrive/sprite/test_images/test03.jpg"
# Out:
# detect: weights=['/content/yolov5/runs/train/sprite/weights/best.pt'], source=/content/drive/MyDrive/sprite/test_images/test03.jpg, data=data/coco128.yaml, imgsz=[1280, 1280], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-120-g3e55763 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/drive/MyDrive/sprite/test_images/test03.jpg: 1280x1280 6 sprites, 34.3ms
# Speed: 1.5ms pre-process, 34.3ms inference, 2.1ms NMS per image at shape (1, 3, 1280, 1280)
# Results saved to runs/detect/exp4

# %%
# !zip -r /content/yolov5.zip /content/yolov5
# Out:
#   adding: content/yolov5/ (stored 0%)
#   adding: content/yolov5/LICENSE (deflated 66%)
#   adding: content/yolov5/requirements.txt (deflated 55%)
#   adding: content/yolov5/.git/ (stored 0%)
#   adding: content/yolov5/.git/FETCH_HEAD (deflated 66%)
#   adding: content/yolov5/.git/description (deflated 14%)
#   adding: content/yolov5/.git/refs/ (stored 0%)
#   adding: content/yolov5/.git/refs/remotes/ (stored 0%)
#   adding: content/yolov5/.git/refs/remotes/origin/ (stored 0%)
#   adding: content/yolov5/.git/refs/remotes/origin/HEAD (stored 0%)
#   adding: content/yolov5/.git/refs/tags/ (stored 0%)
#   adding: content/yolov5/.git/refs/heads/ (stored 0%)
#   adding: content/yolov5/.git/refs/heads/master (stored 0%)
#   adding: content/yolov5/.git/objects/ (stored 0%)
#   adding: content/yolov5/.git/objects/pack/ (stored 0%)
#   adding: content/yolov5/.git/objects/pack/pack-5f34129cbe68fa632c717f62615c250756ca667f.idx (deflated 2%)
# ...
